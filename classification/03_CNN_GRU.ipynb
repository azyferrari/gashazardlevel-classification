# %%
# Import Dataset
import pandas as pd 
data = pd.read_csv('../dataset/data.csv')
data
# Out:
#              MQ2        MQ6       MQ7        MQ9  target
# 0       1.210000   5.080000  0.010000   4.740000       0
# 1       1.810000   5.380000  0.170000   5.640000       0
# 2       1.150000   4.730000  0.010000   0.890000       0
# 3       1.440000   3.640000  0.010000   3.990000       0
# 4       4.910000   0.890000  0.000000   1.510000       0
# ...          ...        ...       ...        ...     ...
# 23995  20.960000  38.610000  0.030000   0.620000       3
# 23996  24.834189  43.240000  0.760000  12.520000       3
# 23997   8.763730  47.740000  0.103432   0.690000       3
# 23998   7.926874  45.689553  0.034926   6.023275       3
# 23999   3.283980  49.160000  0.048796   0.460000       3
#
# [24000 rows x 5 columns]

# %%
# Deklarasi vektor fitur dan variabel target
import numpy as np
from keras.utils import to_categorical

X = data.drop('target',axis=1)
y = data['target']

y = to_categorical(y)

# %%
# Split Data menjadi Training Set dan Test Set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=42)

# %%
# Feature Scaling
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
# Build the Model
import tensorflow as tf
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(filters=64, kernel_size=3,
                      strides=1,
                      activation="relu",
                      padding='causal',
                      input_shape=[4,1]),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.GRU(128, return_sequences=True),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.GRU(128),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(5, activation="softmax"),
    
])

 # Print the model summary 
model.summary()
# Out:
# /Users/amarudinzaidan/.virtualenvs/project/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 4, 64)          │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 2, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 2, 128)         │        74,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 128)            │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 174,469 (681.52 KB)
#  Trainable params: 174,469 (681.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Menghitung Waktu Train
import time
start_time = time.time()

optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
# Compile Model 
model.compile(loss = 'categorical_crossentropy', optimizer = optimizer, metrics = ['accuracy'])

# Fit Model
model.fit(X_train, y_train, epochs = 100, batch_size = 256)

end_time = time.time()
training_time = end_time - start_time
training_minutes = training_time / 60
print("Lama waktu pelatihan: {:.2f} detik".format(training_time))
print("Lama waktu pelatihan: {:.2f} menit".format(training_minutes))
# Out:
# Epoch 1/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.7170 - loss: 0.6432
# Epoch 2/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9544 - loss: 0.1098
# Epoch 3/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9569 - loss: 0.1050
# Epoch 4/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9579 - loss: 0.1032
# Epoch 5/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9737 - loss: 0.0656
# Epoch 6/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9535 - loss: 0.1159
# Epoch 7/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9713 - loss: 0.0652
# Epoch 8/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9618 - loss: 0.0940
# Epoch 9/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9679 - loss: 0.0739
# Epoch 10/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9786 - loss: 0.0554
# Epoch 11/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9623 - loss: 0.0891
# Epoch 12/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9754 - loss: 0.0576
# Epoch 13/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9715 - loss: 0.0660
# Epoch 14/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9762 - loss: 0.0609
# Epoch 15/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9682 - loss: 0.0761
# Epoch 16/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9727 - loss: 0.0695
# Epoch 17/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9738 - loss: 0.0600
# Epoch 18/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9844 - loss: 0.0435
# Epoch 19/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9731 - loss: 0.0693
# Epoch 20/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9813 - loss: 0.0462
# Epoch 21/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9696 - loss: 0.0890
# Epoch 22/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9805 - loss: 0.0529
# Epoch 23/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9787 - loss: 0.0504
# Epoch 24/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9847 - loss: 0.0435
# Epoch 25/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9762 - loss: 0.0592
# Epoch 26/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9808 - loss: 0.0505
# Epoch 27/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9836 - loss: 0.0404
# Epoch 28/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9712 - loss: 0.0728
# Epoch 29/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9709 - loss: 0.0708
# Epoch 30/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9677 - loss: 0.0858
# Epoch 31/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9779 - loss: 0.0537
# Epoch 32/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9829 - loss: 0.0407
# Epoch 33/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9813 - loss: 0.0443
# Epoch 34/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9785 - loss: 0.0567
# Epoch 35/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9813 - loss: 0.0441
# Epoch 36/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9712 - loss: 0.0696
# Epoch 37/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9833 - loss: 0.0418
# Epoch 38/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9884 - loss: 0.0315
# Epoch 39/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9791 - loss: 0.0527
# Epoch 40/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9830 - loss: 0.0403
# Epoch 41/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9800 - loss: 0.0495
# Epoch 42/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9870 - loss: 0.0295
# Epoch 43/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9830 - loss: 0.0430
# Epoch 44/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9743 - loss: 0.0650
# Epoch 45/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9808 - loss: 0.0486
# Epoch 46/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9842 - loss: 0.0375
# Epoch 47/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9840 - loss: 0.0433
# Epoch 48/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9861 - loss: 0.0371
# Epoch 49/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9781 - loss: 0.0584
# Epoch 50/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9856 - loss: 0.0393
# Epoch 51/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9864 - loss: 0.0336
# Epoch 52/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9803 - loss: 0.0450
# Epoch 53/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9706 - loss: 0.0734
# Epoch 54/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9849 - loss: 0.0369
# Epoch 55/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9864 - loss: 0.0345
# Epoch 56/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9871 - loss: 0.0333
# Epoch 57/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9844 - loss: 0.0363
# Epoch 58/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9657 - loss: 0.0959
# Epoch 59/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9865 - loss: 0.0318
# Epoch 60/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9860 - loss: 0.0342
# Epoch 61/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9835 - loss: 0.0416
# Epoch 62/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9868 - loss: 0.0330
# Epoch 63/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9859 - loss: 0.0333
# Epoch 64/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9823 - loss: 0.0438
# Epoch 65/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9861 - loss: 0.0316
# Epoch 66/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9859 - loss: 0.0334
# Epoch 67/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9750 - loss: 0.0617
# Epoch 68/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9852 - loss: 0.0349
# Epoch 69/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9890 - loss: 0.0268
# Epoch 70/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9796 - loss: 0.0536
# Epoch 71/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9844 - loss: 0.0393
# Epoch 72/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9843 - loss: 0.0377
# Epoch 73/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9841 - loss: 0.0396
# Epoch 74/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9813 - loss: 0.0440
# Epoch 75/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9843 - loss: 0.0382
# Epoch 76/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9886 - loss: 0.0302
# Epoch 77/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9760 - loss: 0.0599
# Epoch 78/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9887 - loss: 0.0296
# Epoch 79/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9798 - loss: 0.0475
# Epoch 80/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.9853 - loss: 0.0362
# Epoch 81/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9890 - loss: 0.0292
# Epoch 82/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9883 - loss: 0.0304
# Epoch 83/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9812 - loss: 0.0439
# Epoch 84/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9876 - loss: 0.0302
# Epoch 85/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9860 - loss: 0.0357
# Epoch 86/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.9879 - loss: 0.0302
# Epoch 87/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.9798 - loss: 0.0491
# Epoch 88/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.9871 - loss: 0.0330
# Epoch 89/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.9866 - loss: 0.0364
# Epoch 90/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9836 - loss: 0.0403
# Epoch 91/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9908 - loss: 0.0240
# Epoch 92/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9825 - loss: 0.0427
# Epoch 93/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9833 - loss: 0.0412
# Epoch 94/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9874 - loss: 0.0282
# Epoch 95/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9886 - loss: 0.0278
# Epoch 96/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.9842 - loss: 0.0370
# Epoch 97/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9851 - loss: 0.0324
# Epoch 98/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9864 - loss: 0.0305
# Epoch 99/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9819 - loss: 0.0418
# Epoch 100/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9861 - loss: 0.0371
# Lama waktu pelatihan: 270.33 detik
# Lama waktu pelatihan: 4.51 menit

# %%
# Evaluasi Model
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)

# Predict Model
y_pred_prob = model.predict(X_test, verbose=0)
y_pred = (y_pred_prob > 0.5).astype(int)

# %%
# Menampilkan hasil classification report
from sklearn.metrics import classification_report, f1_score, recall_score, precision_score
print("Report: \n", classification_report(y_test,y_pred,digits=8))
# Out:
# Report:
#                precision    recall  f1-score   support
#
#            0  0.92903226 1.00000000 0.96321070      1440
#            1  0.93727977 0.92361111 0.93039524      1440
#            2  0.96776504 0.93819444 0.95275035      1440
#            3  0.99853801 0.94861111 0.97293447      1440
#            4  0.98090041 0.99861111 0.98967653      1440
#
#    micro avg  0.96193916 0.96180556 0.96187235      7200
#    macro avg  0.96270310 0.96180556 0.96179346      7200
# weighted avg  0.96270310 0.96180556 0.96179346      7200
#  samples avg  0.96180556 0.96180556 0.96180556      7200
# /Users/amarudinzaidan/.virtualenvs/project/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Menampilkan Evaluasi Model
f1 = f1_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
precision = precision_score(y_test, y_pred, average='weighted')

print(f'Accuracy: {accuracy*100:.6f}%')
print(f'f1_score: {f1*100:.6f}%')
print(f'recall_score: {recall*100:.6f}%')
print(f'precision_score: {precision*100:.6f}%')
# Out:
# Accuracy: 96.194446%
# f1_score: 96.179346%
# recall_score: 96.180556%
# precision_score: 96.270310%

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
sns.set()

def draw_confusion_matrix(cm):
    plt.figure(figsize=(12,8))
    sns.heatmap(cm,annot=True,fmt="d", center=0, cmap='autumn') 
    plt.title("Confusion Matrix")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

cm_rf = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
draw_confusion_matrix(cm_rf)
