# %%
# Import Dataset
import pandas as pd 
data = pd.read_csv('../dataset/data.csv')
data
# Out:
#              MQ2        MQ6       MQ7        MQ9  target
# 0       1.210000   5.080000  0.010000   4.740000       0
# 1       1.810000   5.380000  0.170000   5.640000       0
# 2       1.150000   4.730000  0.010000   0.890000       0
# 3       1.440000   3.640000  0.010000   3.990000       0
# 4       4.910000   0.890000  0.000000   1.510000       0
# ...          ...        ...       ...        ...     ...
# 23995  20.960000  38.610000  0.030000   0.620000       3
# 23996  24.834189  43.240000  0.760000  12.520000       3
# 23997   8.763730  47.740000  0.103432   0.690000       3
# 23998   7.926874  45.689553  0.034926   6.023275       3
# 23999   3.283980  49.160000  0.048796   0.460000       3
#
# [24000 rows x 5 columns]

# %%
# Deklarasi vektor fitur dan variabel target
import numpy as np
from keras.utils import to_categorical

X = data.drop('target',axis=1)
y = data['target']

y = to_categorical(y)

# %%
# Split Data menjadi Training Set dan Test Set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=42)

# %%
# Feature Scaling
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
# Build the Model
import tensorflow as tf
model = tf.keras.models.Sequential([
    tf.keras.layers.GRU(128, return_sequences=True, input_shape=(4, 1)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.GRU(128),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(5, activation="softmax"),    
])

 # Print the model summary 
model.summary()
# Out:
# /Users/amarudinzaidan/.virtualenvs/project/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 4, 128)         │        50,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 4, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 128)            │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 150,021 (586.02 KB)
#  Trainable params: 150,021 (586.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Menghitung Waktu Train
import time
start_time = time.time()

optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
# Compile Model 
model.compile(loss = 'categorical_crossentropy', optimizer = optimizer, metrics = ['accuracy'])

# Fit Model
model.fit(X_train, y_train, epochs = 100, batch_size = 256)

end_time = time.time()
training_time = end_time - start_time
training_minutes = training_time / 60
print("Lama waktu pelatihan: {:.2f} detik".format(training_time))
print("Lama waktu pelatihan: {:.2f} menit".format(training_minutes))
# Out:
# Epoch 1/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.6452 - loss: 0.7666
# Epoch 2/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9391 - loss: 0.1468
# Epoch 3/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9315 - loss: 0.1671
# Epoch 4/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9548 - loss: 0.1065
# Epoch 5/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9537 - loss: 0.1065
# Epoch 6/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9617 - loss: 0.0940
# Epoch 7/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9649 - loss: 0.0849
# Epoch 8/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9682 - loss: 0.0716
# Epoch 9/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9586 - loss: 0.0970
# Epoch 10/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9734 - loss: 0.0646
# Epoch 11/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9678 - loss: 0.0776
# Epoch 12/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9684 - loss: 0.0780
# Epoch 13/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9621 - loss: 0.0888
# Epoch 14/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9596 - loss: 0.0956
# Epoch 15/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9687 - loss: 0.0764
# Epoch 16/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9719 - loss: 0.0692
# Epoch 17/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9721 - loss: 0.0687
# Epoch 18/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9685 - loss: 0.0737
# Epoch 19/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9685 - loss: 0.0754
# Epoch 20/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9686 - loss: 0.0736
# Epoch 21/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9790 - loss: 0.0528
# Epoch 22/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9587 - loss: 0.1008
# Epoch 23/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9784 - loss: 0.0556
# Epoch 24/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9646 - loss: 0.0872
# Epoch 25/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9760 - loss: 0.0562
# Epoch 26/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9736 - loss: 0.0666
# Epoch 27/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9761 - loss: 0.0561
# Epoch 28/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9593 - loss: 0.0970
# Epoch 29/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9743 - loss: 0.0645
# Epoch 30/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9835 - loss: 0.0429
# Epoch 31/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9678 - loss: 0.0841
# Epoch 32/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9770 - loss: 0.0571
# Epoch 33/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9815 - loss: 0.0437
# Epoch 34/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9779 - loss: 0.0510
# Epoch 35/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9715 - loss: 0.0688
# Epoch 36/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9775 - loss: 0.0548
# Epoch 37/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9684 - loss: 0.0741
# Epoch 38/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9768 - loss: 0.0523
# Epoch 39/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9678 - loss: 0.0822
# Epoch 40/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9693 - loss: 0.0761
# Epoch 41/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9815 - loss: 0.0468
# Epoch 42/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9785 - loss: 0.0494
# Epoch 43/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9760 - loss: 0.0573
# Epoch 44/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9799 - loss: 0.0478
# Epoch 45/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9795 - loss: 0.0492
# Epoch 46/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9806 - loss: 0.0444
# Epoch 47/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9795 - loss: 0.0514
# Epoch 48/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9663 - loss: 0.0795
# Epoch 49/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9809 - loss: 0.0437
# Epoch 50/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9780 - loss: 0.0529
# Epoch 51/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9841 - loss: 0.0384
# Epoch 52/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9709 - loss: 0.0662
# Epoch 53/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9776 - loss: 0.0514
# Epoch 54/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9624 - loss: 0.0930
# Epoch 55/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9818 - loss: 0.0455
# Epoch 56/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9829 - loss: 0.0397
# Epoch 57/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9765 - loss: 0.0582
# Epoch 58/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9776 - loss: 0.0560
# Epoch 59/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9773 - loss: 0.0552
# Epoch 60/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9824 - loss: 0.0460
# Epoch 61/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9790 - loss: 0.0506
# Epoch 62/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9832 - loss: 0.0417
# Epoch 63/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9859 - loss: 0.0352
# Epoch 64/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9594 - loss: 0.1043
# Epoch 65/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9694 - loss: 0.0710
# Epoch 66/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9878 - loss: 0.0309
# Epoch 67/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9762 - loss: 0.0589
# Epoch 68/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9750 - loss: 0.0604
# Epoch 69/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9872 - loss: 0.0307
# Epoch 70/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9834 - loss: 0.0408
# Epoch 71/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9857 - loss: 0.0354
# Epoch 72/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9844 - loss: 0.0373
# Epoch 73/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9802 - loss: 0.0490
# Epoch 74/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9878 - loss: 0.0290
# Epoch 75/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9868 - loss: 0.0332
# Epoch 76/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9758 - loss: 0.0653
# Epoch 77/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9839 - loss: 0.0377
# Epoch 78/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9849 - loss: 0.0397
# Epoch 79/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9827 - loss: 0.0427
# Epoch 80/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9796 - loss: 0.0508
# Epoch 81/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9792 - loss: 0.0461
# Epoch 82/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9830 - loss: 0.0415
# Epoch 83/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9785 - loss: 0.0507
# Epoch 84/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9845 - loss: 0.0356
# Epoch 85/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9871 - loss: 0.0299
# Epoch 86/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9870 - loss: 0.0315
# Epoch 87/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9869 - loss: 0.0337
# Epoch 88/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9737 - loss: 0.0661
# Epoch 89/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9789 - loss: 0.0518
# Epoch 90/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9840 - loss: 0.0373
# Epoch 91/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9796 - loss: 0.0492
# Epoch 92/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9828 - loss: 0.0406
# Epoch 93/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9859 - loss: 0.0338
# Epoch 94/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9848 - loss: 0.0354
# Epoch 95/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9829 - loss: 0.0408
# Epoch 96/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9833 - loss: 0.0443
# Epoch 97/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9887 - loss: 0.0299
# Epoch 98/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9838 - loss: 0.0400
# Epoch 99/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9877 - loss: 0.0301
# Epoch 100/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9779 - loss: 0.0607
# Lama waktu pelatihan: 191.75 detik
# Lama waktu pelatihan: 3.20 menit

# %%
# Evaluasi Model
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)

# Predict Model
y_pred_prob = model.predict(X_test, verbose=0)
y_pred = (y_pred_prob > 0.5).astype(int)

# %%
# Menampilkan hasil classification report
from sklearn.metrics import classification_report, f1_score, recall_score, precision_score
print("Report: \n", classification_report(y_test,y_pred,digits=8))
# Out:
# Report:
#                precision    recall  f1-score   support
#
#            0  0.99515235 0.99791667 0.99653259      1440
#            1  0.99159075 0.98263889 0.98709452      1440
#            2  0.98602376 0.97986111 0.98293278      1440
#            3  0.98205659 0.98819444 0.98511596      1440
#            4  0.98964803 0.99583333 0.99273105      1440
#
#    micro avg  0.98888889 0.98888889 0.98888889      7200
#    macro avg  0.98889430 0.98888889 0.98888138      7200
# weighted avg  0.98889430 0.98888889 0.98888138      7200
#  samples avg  0.98888889 0.98888889 0.98888889      7200

# %%
# Menampilkan Evaluasi Model
f1 = f1_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
precision = precision_score(y_test, y_pred, average='weighted')

print(f'Accuracy: {accuracy*100:.6f}%')
print(f'f1_score: {f1*100:.6f}%')
print(f'recall_score: {recall*100:.6f}%')
print(f'precision_score: {precision*100:.6f}%')
# Out:
# Accuracy: 98.888886%
# f1_score: 98.888138%
# recall_score: 98.888889%
# precision_score: 98.889430%

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
sns.set()

def draw_confusion_matrix(cm):
    plt.figure(figsize=(12,8))
    sns.heatmap(cm,annot=True,fmt="d", center=0, cmap='autumn') 
    plt.title("Confusion Matrix")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

cm_rf = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
draw_confusion_matrix(cm_rf)
