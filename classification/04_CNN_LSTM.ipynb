# %%
# Import Dataset
import pandas as pd 
data = pd.read_csv('../dataset/data.csv')
data
# Out:
#              MQ2        MQ6       MQ7        MQ9  target
# 0       1.210000   5.080000  0.010000   4.740000       0
# 1       1.810000   5.380000  0.170000   5.640000       0
# 2       1.150000   4.730000  0.010000   0.890000       0
# 3       1.440000   3.640000  0.010000   3.990000       0
# 4       4.910000   0.890000  0.000000   1.510000       0
# ...          ...        ...       ...        ...     ...
# 23995  20.960000  38.610000  0.030000   0.620000       3
# 23996  24.834189  43.240000  0.760000  12.520000       3
# 23997   8.763730  47.740000  0.103432   0.690000       3
# 23998   7.926874  45.689553  0.034926   6.023275       3
# 23999   3.283980  49.160000  0.048796   0.460000       3
#
# [24000 rows x 5 columns]

# %%
# Deklarasi vektor fitur dan variabel target
import numpy as np
from keras.utils import to_categorical

X = data.drop('target',axis=1)
y = data['target']

y = to_categorical(y)

# %%
# Split Data menjadi Training Set dan Test Set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=42)

# %%
# Feature Scaling
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
# Build the Model
import tensorflow as tf
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(filters=64, kernel_size=3,
                      strides=1,
                      activation="relu",
                      padding='causal',
                      input_shape=[4,1]),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.LSTM(128, return_sequences=True),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.LSTM(128),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(5, activation="softmax"),
    
])

 # Print the model summary 
model.summary()
# Out:
# /Users/amarudinzaidan/.virtualenvs/project/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 4, 64)          │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 2, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 2, 128)         │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 231,301 (903.52 KB)
#  Trainable params: 231,301 (903.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Menghitung Waktu Train
import time
start_time = time.time()

optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
# Compile Model 
model.compile(loss = 'categorical_crossentropy', optimizer = optimizer, metrics = ['accuracy'])

# Fit Model
model.fit(X_train, y_train, epochs = 100, batch_size = 256)

end_time = time.time()
training_time = end_time - start_time
training_minutes = training_time / 60
print("Lama waktu pelatihan: {:.2f} detik".format(training_time))
print("Lama waktu pelatihan: {:.2f} menit".format(training_minutes))
# Out:
# Epoch 1/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.6027 - loss: 0.8452
# Epoch 2/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9592 - loss: 0.1022
# Epoch 3/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9673 - loss: 0.0828
# Epoch 4/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9629 - loss: 0.0931
# Epoch 5/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9508 - loss: 0.1134
# Epoch 6/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9589 - loss: 0.1088
# Epoch 7/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9645 - loss: 0.0855
# Epoch 8/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9686 - loss: 0.0776
# Epoch 9/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9699 - loss: 0.0693
# Epoch 10/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9709 - loss: 0.0677
# Epoch 11/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9801 - loss: 0.0509
# Epoch 12/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9756 - loss: 0.0622
# Epoch 13/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9738 - loss: 0.0745
# Epoch 14/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9674 - loss: 0.0811
# Epoch 15/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9716 - loss: 0.0670
# Epoch 16/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9755 - loss: 0.0578
# Epoch 17/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9716 - loss: 0.0695
# Epoch 18/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9655 - loss: 0.0812
# Epoch 19/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9807 - loss: 0.0472
# Epoch 20/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9771 - loss: 0.0528
# Epoch 21/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9780 - loss: 0.0551
# Epoch 22/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9696 - loss: 0.0854
# Epoch 23/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9807 - loss: 0.0476
# Epoch 24/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9844 - loss: 0.0398
# Epoch 25/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9819 - loss: 0.0460
# Epoch 26/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9789 - loss: 0.0629
# Epoch 27/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9752 - loss: 0.0590
# Epoch 28/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9784 - loss: 0.0511
# Epoch 29/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9745 - loss: 0.0650
# Epoch 30/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9731 - loss: 0.0663
# Epoch 31/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9777 - loss: 0.0554
# Epoch 32/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9789 - loss: 0.0520
# Epoch 33/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9822 - loss: 0.0440
# Epoch 34/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9846 - loss: 0.0403
# Epoch 35/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9788 - loss: 0.0527
# Epoch 36/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9797 - loss: 0.0498
# Epoch 37/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9826 - loss: 0.0420
# Epoch 38/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9845 - loss: 0.0397
# Epoch 39/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9758 - loss: 0.0576
# Epoch 40/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9813 - loss: 0.0465
# Epoch 41/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9870 - loss: 0.0326
# Epoch 42/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9708 - loss: 0.0687
# Epoch 43/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9770 - loss: 0.0546
# Epoch 44/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9843 - loss: 0.0395
# Epoch 45/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9703 - loss: 0.0729
# Epoch 46/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9870 - loss: 0.0340
# Epoch 47/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9745 - loss: 0.0608
# Epoch 48/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9729 - loss: 0.0622
# Epoch 49/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9815 - loss: 0.0464
# Epoch 50/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9858 - loss: 0.0351
# Epoch 51/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.9797 - loss: 0.0493
# Epoch 52/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9800 - loss: 0.0531
# Epoch 53/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9885 - loss: 0.0298
# Epoch 54/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9827 - loss: 0.0459
# Epoch 55/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9880 - loss: 0.0282
# Epoch 56/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9615 - loss: 0.1181
# Epoch 57/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9818 - loss: 0.0423
# Epoch 58/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9860 - loss: 0.0338
# Epoch 59/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9877 - loss: 0.0305
# Epoch 60/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9844 - loss: 0.0369
# Epoch 61/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9835 - loss: 0.0426
# Epoch 62/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9883 - loss: 0.0304
# Epoch 63/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9835 - loss: 0.0404
# Epoch 64/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9907 - loss: 0.0234
# Epoch 65/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9870 - loss: 0.0329
# Epoch 66/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9861 - loss: 0.0321
# Epoch 67/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9757 - loss: 0.0625
# Epoch 68/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9851 - loss: 0.0359
# Epoch 69/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9844 - loss: 0.0358
# Epoch 70/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9793 - loss: 0.0546
# Epoch 71/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9895 - loss: 0.0276
# Epoch 72/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9897 - loss: 0.0287
# Epoch 73/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9882 - loss: 0.0292
# Epoch 74/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9850 - loss: 0.0402
# Epoch 75/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9921 - loss: 0.0247
# Epoch 76/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9815 - loss: 0.0437
# Epoch 77/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.9902 - loss: 0.0265
# Epoch 78/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9864 - loss: 0.0310
# Epoch 79/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9830 - loss: 0.0400
# Epoch 80/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9882 - loss: 0.0317
# Epoch 81/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9865 - loss: 0.0328
# Epoch 82/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9912 - loss: 0.0224
# Epoch 83/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9868 - loss: 0.0303
# Epoch 84/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.9891 - loss: 0.0269
# Epoch 85/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.9867 - loss: 0.0382
# Epoch 86/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9899 - loss: 0.0256
# Epoch 87/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.9903 - loss: 0.0232
# Epoch 88/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9894 - loss: 0.0269
# Epoch 89/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9759 - loss: 0.0573
# Epoch 90/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9887 - loss: 0.0278
# Epoch 91/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9840 - loss: 0.0370
# Epoch 92/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9865 - loss: 0.0311
# Epoch 93/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9869 - loss: 0.0316
# Epoch 94/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9914 - loss: 0.0238
# Epoch 95/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9889 - loss: 0.0266
# Epoch 96/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9823 - loss: 0.0469
# Epoch 97/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9806 - loss: 0.0467
# Epoch 98/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9851 - loss: 0.0324
# Epoch 99/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9912 - loss: 0.0219
# Epoch 100/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9862 - loss: 0.0360
# Lama waktu pelatihan: 271.00 detik
# Lama waktu pelatihan: 4.52 menit

# %%
# Evaluasi Model
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)

# Predict Model
y_pred_prob = model.predict(X_test, verbose=0)
y_pred = (y_pred_prob > 0.5).astype(int)

# %%
# Menampilkan hasil classification report
from sklearn.metrics import classification_report, f1_score, recall_score, precision_score
print("Report: \n", classification_report(y_test,y_pred,digits=8))
# Out:
# Report:
#                precision    recall  f1-score   support
#
#            0  1.00000000 0.99236111 0.99616591      1440
#            1  0.96830748 0.99722222 0.98255217      1440
#            2  0.97362942 0.97430556 0.97396737      1440
#            3  0.99574166 0.97430556 0.98490698      1440
#            4  0.99860821 0.99652778 0.99756691      1440
#
#    micro avg  0.98708154 0.98694444 0.98701299      7200
#    macro avg  0.98725736 0.98694444 0.98703187      7200
# weighted avg  0.98725736 0.98694444 0.98703187      7200
#  samples avg  0.98694444 0.98694444 0.98694444      7200
# /Users/amarudinzaidan/.virtualenvs/project/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Menampilkan Evaluasi Model
f1 = f1_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
precision = precision_score(y_test, y_pred, average='weighted')

print(f'Accuracy: {accuracy*100:.6f}%')
print(f'f1_score: {f1*100:.6f}%')
print(f'recall_score: {recall*100:.6f}%')
print(f'precision_score: {precision*100:.6f}%')
# Out:
# Accuracy: 98.708332%
# f1_score: 98.703187%
# recall_score: 98.694444%
# precision_score: 98.725736%

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
sns.set()

def draw_confusion_matrix(cm):
    plt.figure(figsize=(12,8))
    sns.heatmap(cm,annot=True,fmt="d", center=0, cmap='autumn') 
    plt.title("Confusion Matrix")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

cm_rf = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
draw_confusion_matrix(cm_rf)
